# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: agg

# %%
x = np.arange(0, 10, 0.1)

fig = plt.gcf()
fig.set_size_inches(9.25, 5.25)
fig.savefig('test2png.png', dpi=100)


# fig, axs = plt.subplots(1,2)
x = [ 25600, 51200, 102400, 204800, 409600, 819200, 1638400, 3276800, 6553600, 13107200, 26214400, 52428800, 104857600 ]
y_2 = [ 0.00150, 0.000464, 0.001469, 0.001700, 0.003357, 0.008130, 0.015468, 0.035492, 0.078966, 0.187463, 0.313626,  0.535562, 1.072317 ]
y_4 = [ 0.000350, 0.000092, 0.001289, 0.001209, 0.002615, 0.006905, 0.019416, 0.043729, 0.093870, 0.187400, 0.313784, 0.669000, 1.129357 ]
y_8 = [0.000275, 0.000610, 0.001566, 0.002538, 0.002860, 0.007608, 0.018129, 0.048354, 0.120047, 0.173925,  0.377420, 0.748900, 1.370626]

plt.plot(x, y_2, label="n = 2")
plt.plot(x, y_4, label="n = 4")
plt.plot(x, y_8, label="n = 8")

plt.plot()

plt.xlabel("m = text length")
plt.ylabel("time (sec)")
plt.title("KMP algorithm")

plt.legend(title = "n = pattern length")

# [line] = axs[0].plot(x, x*2)


plt.show()
